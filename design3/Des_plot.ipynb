# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import spline
# %matplotlib inline
import csv
import pandas as pd
import matplotlib

# %%
y1pos = np.genfromtxt('dmd11.txt',delimiter=' ')
y2pos = np.genfromtxt('dmd21.txt',delimiter=' ')
y1neg = np.genfromtxt('dmd11neg.txt',delimiter=' ')
y2neg = np.genfromtxt('dmd21neg.txt',delimiter=' ')

# %%
x1pos=np.arange(.2,6.4,.2)
x1neg=np.arange(-6.2,0,.2)
x2pos=np.arange(.2,6.4,.2)
x2neg=np.arange(-6.2,0,.2)

# %%
y1=np.append(y1neg,y1pos)
x1=np.append(x1neg,x1pos)
y2=np.append(y2neg,y2pos)
x2=np.append(x2neg,x2pos)

# %%
xa=np.linspace(x1.min(),x1.max(),1000)
xb=np.linspace(x2.min(),x2.max(),1000)
ya=spline(x1,y1,xa)
yb=spline(x2,y2,xb)
plt.plot(xa,ya)
plt.plot(xb,yb)
plt.xlabel("k")
plt.ylabel("DMD [ns\km]")
plt.title("DMD VS K ")
plt.grid()
plt.show()

# %%
y2
# Out:
# array([ 1.87916 ,  1.87941 ,  1.87968 ,  1.87999 ,  1.88035 ,  1.88074 ,
#         1.88119 ,  1.8817  ,  1.88228 ,  1.88295 ,  1.88372 ,  1.88461 ,
#         1.88565 ,  1.88688 ,  1.88832 ,  1.89004 ,  1.8921  ,  1.89458 ,
#         1.89761 ,  1.90134 ,  1.90598 ,  1.91182 ,  1.91927 ,  1.92889 ,
#         1.94145 ,  1.95798 ,  1.97961 ,  2.00652 ,  2.03284 ,  2.00901 ,
#        -1.5722  ,  0.492999,  0.436569,  0.426165,  0.425331,  0.426746,
#         0.428456,  0.429953,  0.431146,  0.432069,  0.432773,  0.433304,
#         0.433711,  0.434025,  0.434262,  0.434447,  0.434595,  0.434709,
#         0.434797,  0.434866,  0.434921,  0.434963,  0.434998,  0.435023,
#         0.435041,  0.435061,  0.435066,  0.435076,  0.435084,  0.435086,
#         0.435091,  0.435094])

# %%
plt.figure()
plt.rcParams.update({'font.size': 8})

x1pos_smooth=np.linspace(x1pos.min(),x1pos.max(),300)
y1pos_smooth=spline(x1pos,y1pos,x1pos_smooth)
plt.subplot(2,2,1)
plt.plot(x1pos_smooth,y1pos_smooth)
plt.xlabel("k")
plt.ylabel("DMD [ns\km]")
plt.title("DMD VS K ")

x2pos_smooth=np.linspace(x2pos.min(),x2pos.max(),300)
y2pos_smooth=spline(x2pos,y2pos,x2pos_smooth)
plt.subplot(2,2,2)
plt.plot(x2pos_smooth,y2pos_smooth)
plt.xlabel("k")
plt.ylabel("DMD [ns\km]")
plt.title("DMD VS K ")

x1neg_smooth=np.linspace(x1neg.min(),x1neg.max(),300)
y1neg_smooth=spline(x1neg,y1neg,x1neg_smooth)
plt.subplot(2,2,3)
plt.plot(x1neg_smooth,y1neg_smooth)
plt.xlabel("k")
plt.ylabel("DMD [ns\km]")
plt.title("DMD VS K ")

x2neg_smooth=np.linspace(x2neg.min(),x2neg.max(),300)
y2neg_smooth=spline(x2neg,y2neg,x2neg_smooth)
plt.subplot(2,2,4)
plt.plot(x2neg_smooth,y2neg_smooth)
plt.xlabel("k")
plt.ylabel("DMD [ns\km]")
plt.title("DMD VS K ")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,5))
y_formatter = matplotlib.ticker.ScalarFormatter(useOffset=False)

neff0 = np.genfromtxt('neff_01.txt',delimiter=' ')
neff1 = np.genfromtxt('neff_11.txt',delimiter=' ')
neff2 = np.genfromtxt('neff_21.txt',delimiter=' ')
#splie fit
neff0_smooth=spline(x1pos,neff0,x1pos_smooth)
neff1_smooth=spline(x1pos,neff1,x1pos_smooth)
neff2_smooth=spline(x1pos,neff2,x1pos_smooth)

plt.subplot(1,2,1)
plt.plot(x1pos_smooth,neff0_smooth)
plt.plot(x1pos_smooth,neff1_smooth)
plt.plot(x1pos_smooth,neff2_smooth)
plt.xlabel("k")
plt.ylabel("DMD [ns\km]")
plt.title("DMD VS K ")
plt.gca().yaxis.set_major_formatter(y_formatter)
#plt.show()
###########
neff0neg = np.genfromtxt('neff_01neg.txt',delimiter=' ')
neff1neg = np.genfromtxt('neff_11neg.txt',delimiter=' ')
neff2neg = np.genfromtxt('neff_21neg.txt',delimiter=' ')
#splie fit
neff0neg_smooth=spline(x1pos,neff0,x1neg_smooth)
neff1neg_smooth=spline(x1pos,neff1,x1neg_smooth)
neff2neg_smooth=spline(x1pos,neff2,x1neg_smooth)

plt.subplot(1,2,2)
plt.plot(x1neg,neff0neg)
plt.plot(x1neg,neff1neg)
plt.plot(x1neg,neff2neg)
plt.xlabel("k")
plt.ylabel("DMD [ns\km]")
plt.title("DMD VS K ")
plt.gca().yaxis.set_major_formatter(y_formatter)
plt.tight_layout()
plt.show()

# %%
x1=np.arange(.2,6.2,.2)
x1neg=np.arange(-.2,-6.2,-.2)

# %%
x1_smooth=np.linspace(x1.min(),x1.max(),300)
y1_smooth=spline(x1,y1,x1_smooth)
y2_smooth=spline(x1,y2,x1_smooth)
#y3_smooth=spline(x1,y3,x1_smooth)
#y4_smooth=spline(x1,y4,x1_smooth)
#y5_smooth=spline(x1,y5,x1_smooth)
x1neg_smooth=np.linspace(x1neg.max(),x1neg.min(),300)
y1neg_smooth=spline(x1neg,y1neg,x1neg_smooth)
y2neg_smooth=spline(x1neg,y2neg,x1neg_smooth)

# %%
#plt.plot(x1_smooth,y1_smooth)
plt.plot(x1_smooth,y2_smooth)
plt.plot(x1neg,y2neg)
#y1neg_smooth

# %%
neff0 = np.genfromtxt('neff_01.txt',delimiter=' ')
neff1 = np.genfromtxt('neff_11.txt',delimiter=' ')
neff2 = np.genfromtxt('neff_21.txt',delimiter=' ')
#y1 = np.genfromtxt('dmd_11.txt',delimiter=' ')
#y1 = np.genfromtxt('dmd_11.txt',delimiter=' ')
#y1 = np.genfromtxt('dmd_11.txt',delimiter=' ')

# %%
neff0_smooth=spline(x1,neff0,x1_smooth)
neff1_smooth=spline(x1,neff1,x1_smooth)
neff2_smooth=spline(x1,neff2,x1_smooth)
#y3_smooth=spline(x1,y3,x1_smooth)
#y4_smooth=spline(x1,y4,x1_smooth)
#y5_smooth=spline(x1,y5,x1_smooth)

# %%
plt.plot(x1_smooth,neff0_smooth)
plt.plot(x1_smooth,neff1_smooth)
plt.plot(x1_smooth,neff2_smooth)
