# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import spline
# %matplotlib inline
import csv
import pandas as pd
import matplotlib

# %%
y1 = np.genfromtxt('dmd11.txt',delimiter=' ')
y2 = np.genfromtxt('dmd21.txt',delimiter=' ')
#y1neg = np.genfromtxt('dmd11neg.txt',delimiter=' ')
#y2neg = np.genfromtxt('dmd21neg.txt',delimiter=' ')

# %%
x1=np.arange(3,9.2,.2)
#x1neg=np.arange(-6.2,0,.2)
x2=np.arange(3,9.2,.2)
#x2neg=np.arange(-6.2,0,.2)

# %%
y1=np.append(y1neg,y1pos)
x1=np.append(x1neg,x1pos)
y2=np.append(y2neg,y2pos)
x2=np.append(x2neg,x2pos)
# Out:
# --------------------------------------------------------
# NameError              Traceback (most recent call last)
# <ipython-input-14-eeeb56f8af3f> in <module>()
# ----> 1 y1=np.append(y1neg,y1pos)
#       2 x1=np.append(x1neg,x1pos)
#       3 y2=np.append(y2neg,y2pos)
#       4 x2=np.append(x2neg,x2pos)
#
# NameError: name 'y1neg' is not defined

# %%
xa=np.linspace(x1.min(),x1.max(),1000)
xb=np.linspace(x2.min(),x2.max(),1000)
ya=spline(x1,y1,xa)
yb=spline(x2,y2,xb)
plt.plot(xa,ya,label='T(LP11-LP01)')
plt.plot(xb,yb,label='T(LP21-LP01)')
plt.xlabel("r")
plt.ylabel("DMD [ns\km]")
plt.title("DMD VS Radius of Inner Profile ")
plt.grid()
#plt.show()
plt.savefig('detailed_dmd.png')

# %%
y2
# Out:
# array([ 1.20584 ,  1.1763  ,  1.14766 ,  1.11992 ,  1.09303 ,  1.06698 ,
#         1.04175 ,  1.01729 ,  0.993594,  0.970638,  0.948389,  0.926834,
#         0.905944,  0.885699,  0.866077,  0.847055,  0.828619,  0.810741,
#         0.793406,  0.77659 ,  0.760277,  0.744454,  0.729098,  0.714198,
#         0.699735,  0.685692,  0.672053,  0.65881 ,  0.645945,  0.633445,
#         0.621292])

# %%
plt.figure()
plt.rcParams.update({'font.size': 8})

x1_smooth=np.linspace(x1.min(),x1.max(),300)
y1_smooth=spline(x1,y1,x1_smooth)
plt.subplot(1,2,1)
plt.plot(x1_smooth,y1_smooth)
plt.xlabel("k")
plt.ylabel("DMD [ns\km]")
plt.title("DMD VS K ")

x2_smooth=np.linspace(x2.min(),x2.max(),300)
y2_smooth=spline(x2,y2,x2_smooth)
plt.subplot(1,2,2)
plt.plot(x2_smooth,y2_smooth)
plt.xlabel("k")
plt.ylabel("DMD [ns\km]")
plt.title("DMD VS K ")

plt.tight_layout()
#plt.show()
plt.savefig('seperate_dmd.png')

# %%
plt.figure(figsize=(7,5))
y_formatter = matplotlib.ticker.ScalarFormatter(useOffset=False)

neff0 = np.genfromtxt('neff_01.txt',delimiter=' ')
neff1 = np.genfromtxt('neff_11.txt',delimiter=' ')
neff2 = np.genfromtxt('neff_21.txt',delimiter=' ')
#splie fit
neff0_smooth=spline(x1,neff0,x1_smooth)
neff1_smooth=spline(x1,neff1,x1_smooth)
neff2_smooth=spline(x1,neff2,x1_smooth)

plt.subplot(1,2,1)
plt.plot(x1_smooth,neff0_smooth,'r')
plt.plot(x1_smooth,neff1_smooth,'g')
plt.plot(x1_smooth,neff2_smooth,'b')
plt.xlabel("r")
plt.ylabel("N Effective")
plt.title("N Effective Vs r ")
plt.gca().yaxis.set_major_formatter(y_formatter)
#plt.show()
###########

plt.gca().yaxis.set_major_formatter(y_formatter)
plt.tight_layout()
#plt.show()
plt.savefig('Neffective.png')

# %%
x1=np.arange(.2,6.2,.2)
x1neg=np.arange(-.2,-6.2,-.2)

# %%
x1_smooth=np.linspace(x1.min(),x1.max(),300)
y1_smooth=spline(x1,y1,x1_smooth)
y2_smooth=spline(x1,y2,x1_smooth)
#y3_smooth=spline(x1,y3,x1_smooth)
#y4_smooth=spline(x1,y4,x1_smooth)
#y5_smooth=spline(x1,y5,x1_smooth)
x1neg_smooth=np.linspace(x1neg.max(),x1neg.min(),300)
y1neg_smooth=spline(x1neg,y1neg,x1neg_smooth)
y2neg_smooth=spline(x1neg,y2neg,x1neg_smooth)

# %%
#plt.plot(x1_smooth,y1_smooth)
plt.plot(x1_smooth,y2_smooth)
plt.plot(x1neg,y2neg)
#y1neg_smooth

# %%
neff0 = np.genfromtxt('neff_01.txt',delimiter=' ')
neff1 = np.genfromtxt('neff_11.txt',delimiter=' ')
neff2 = np.genfromtxt('neff_21.txt',delimiter=' ')
#y1 = np.genfromtxt('dmd_11.txt',delimiter=' ')
#y1 = np.genfromtxt('dmd_11.txt',delimiter=' ')
#y1 = np.genfromtxt('dmd_11.txt',delimiter=' ')

# %%
neff0_smooth=spline(x1,neff0,x1_smooth)
neff1_smooth=spline(x1,neff1,x1_smooth)
neff2_smooth=spline(x1,neff2,x1_smooth)
#y3_smooth=spline(x1,y3,x1_smooth)
#y4_smooth=spline(x1,y4,x1_smooth)
#y5_smooth=spline(x1,y5,x1_smooth)

# %%
plt.plot(x1_smooth,neff0_smooth)
plt.plot(x1_smooth,neff1_smooth)
plt.plot(x1_smooth,neff2_smooth)
